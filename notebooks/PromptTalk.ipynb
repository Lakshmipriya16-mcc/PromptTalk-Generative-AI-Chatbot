# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\laksh\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\laksh\anaconda3\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\laksh\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\laksh\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\laksh\anaconda3\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\laksh\anaconda3\lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\laksh\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\laksh\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\laksh\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\laksh\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\laksh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\laksh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\laksh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\laksh\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\laksh\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\laksh\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\laksh\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import openai

# %%
import os
os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY"

# %%
def prompttalk_chatbot(user_input):
    response = "AI response here"
    return response

# %%
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("PromptTalk: TakeCare!")
        break
    print("PromptTalk:", prompttalk_chatbot(user_input))
# Out:
# You:  Hello
# PromptTalk: AI response here
# You:  how are you?
# PromptTalk: AI response here
# You:  exit
# PromptTalk: TakeCare!
